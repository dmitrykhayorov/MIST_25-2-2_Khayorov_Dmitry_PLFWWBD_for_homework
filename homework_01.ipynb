# %%
print("Меня зовут Дмитрий, и я готов(а) страдать на курсе!")
# Out:
# Меня зовут Дмитрий, и я готов(а) страдать на курсе!

# %% [markdown]
# Скрин прилогается:
# ![screen](./assets/screen.png)

# %% [markdown]
# ## О себе.
# Пара интересных и не очень фактов:
# * Студент МИСИС;
# * Сотрудник Сбера;

# %% [markdown]
# Найдите остаток от деления 77 на 2

# %%
print(77 % 2)
# Out:
# 1

# %% [markdown]
# Узнайте четное ли число 22

# %%
print("22 четное? ответ:", 22%2==0)
# Out:
# 22 четное? ответ: True

# %% [markdown]
# Посчитайте 86 в степени 7

# %%
print(86**7)
# Out:
# 34792782221696

# %% [markdown]
# Найдите квадратный корень из 3686400

# %%
print(3686400 ** 0.5)
# Out:
# 1920.0
